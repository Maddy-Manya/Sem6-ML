# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()

# %%
# here
from sklearn.linear_model import LinearRegression

# %%
x = np.array([10,
15, 
20,     
25, 
30]).reshape(-1, 1)

y =  [1003,
1005,
1010,
1011,
1014]

reg = LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
reg.coef_, reg.intercept_
# Out:
# (array([0.56]), 997.4)

# %%
m = reg.coef_ # array
c = reg.intercept_
reg.predict([ [5]])
# Out:
# array([1000.2])

# %%
# plotting
ax = plt.axes()
ax.scatter(x,y)
ax.set_xlabel("Temperature")
ax.set_ylabel("Pressure")
ax.axline((0, c) ,slope=m[0], color='red')

# %%
reg.predict([ [5] , [10] , [15]])
# Out:
# array([1000.2, 1003. , 1005.8])
